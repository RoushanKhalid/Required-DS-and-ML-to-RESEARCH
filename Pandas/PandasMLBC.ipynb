# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Basic data structures in pandas
# Pandas provides two types of classes for handling data:
#
# ###Series: a one-dimensional labeled array holding data of any type such as integers, strings, Python objects etc.
#
# ###DataFrame: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# #Null value

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s = s.fillna(0)  # Replace np.nan with 0
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    0.0
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s = s.astype(int)  # Convert to integer type
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    0
# 4    6
# 5    8
# dtype: int64

# %% [markdown]
# #Drop Null value

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s = s.dropna()  # Remove rows with np.nan
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s = s.astype(int)  # Convert to integer type
s
# Out:
# 0    1
# 1    3
# 2    5
# 4    6
# 5    8
# dtype: int64

# %%
dates = pd.date_range("20230829", periods=10)
dates
# Out:
# DatetimeIndex(['2023-08-29', '2023-08-30', '2023-08-31', '2023-09-01',
#                '2023-09-02', '2023-09-03', '2023-09-04', '2023-09-05',
#                '2023-09-06', '2023-09-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2002-07-23', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
print(df)
# Out:
#                    A         B         C         D
# 2002-07-23 -2.038596  1.089201 -0.683830  2.477757
# 2002-07-24  0.199445 -1.659535  0.579337  0.939578
# 2002-07-25  0.138077 -0.647220 -0.785183 -0.836127
# 2002-07-26 -0.321334  0.395215  1.541114  0.546346
# 2002-07-27  0.478053  0.125956  1.152038  0.627335
# 2002-07-28  0.106956 -0.573014  0.002408 -0.142985

# %%
index=list(range(4))
index
# Out:
# [0, 1, 2, 3]

# %%
index2=list(range(4,10,2))
index2
# Out:
# [4, 6, 8]

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20241106"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2024-11-06  1.0  3   test  foo
# 1  1.0 2024-11-06  1.0  3  train  foo
# 2  1.0 2024-11-06  1.0  3   test  foo
# 3  1.0 2024-11-06  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Breast_Cancer_Diagnostic.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %% [markdown]
# ###Mean calculation:
# Consider the data set: 10, 20, 36, 12, 35, 40, 36, 30, 36, 40. The mean is calculated as follows:
# {x} = {10 + 20 + 36 + 12 + 35 + 40 + 36 + 30 + 36 + 40}/{10} = {295}/{10} = 29.5

# %% [markdown]
# ##Test: x= 40,45,77,85
# ###Find the mean

# %% [markdown]
# ![White and Green Simple  Professional Business Project Presentation.png](data:image/png;base64,...)

# %% [markdown]
# ##For odd number of ovservation
# ![image.png](data:image/png;base64,...)
#
#
# ##For Even Number of observation
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Example: 4, 17, 77, 25, 22, 23, 92, 82, 40, 24, 14, 12, 67, 23, 29
#
# ##When we put those numbers in the order, we have: 4, 12, 14, 17, 22, 23, 23, 24, 25, 29, 40, 67, 77, 82, 92,
#
# Median is = (15+1/2) th term
#
#           = 8 th term
#
#           Answer is 24

# %% [markdown]
# ##Example-2: 2,6,9,12,12,15
# Median
#
#       = ((6/2)th +((6/2)+1)th )/2
#
#        = (9+12)/2
#        = 10.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Mode = Value repeated most number of times = 12

# %%
import numpy as np
import pandas as pd
from google.colab import drive


x = [2, 6, 9, 12, 12, 15, 15]

# Using pandas
df = pd.DataFrame({'col':x})
modes = df['col'].mode().tolist()
print("Mode(s) using pandas:", modes)
# Out:
# Mode(s) using pandas: [12, 15]

# %%
df.shape
# Out:
# (7, 1)

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
temp=data

# %%
temp.T
# Out:
#                               0         1         2         3         4    \
# id                         842302    842517  84300903  84348301  84358402
# diagnosis                       M         M         M         M         M
# radius_mean                 17.99     20.57     19.69     11.42     20.29
# texture_mean                10.38     17.77     21.25     20.38     14.34
# perimeter_mean              122.8     132.9     130.0     77.58     135.1
# area_mean                  1001.0    1326.0    1203.0     386.1    1297.0
# smoothness_mean            0.1184   0.08474    0.1096    0.1425    0.1003
# compactness_mean           0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean             0.3001    0.0869    0.1974    0.2414     0.198
# concave points_mean        0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean              0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean    0.07871   0.05667   0.05999   0.09744   0.05883
# ...

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.sort_index(axis=1, ascending=True)
# Out:
#      Unnamed: 32  area_mean  area_se  area_worst  compactness_mean  \
# 0            NaN     1001.0   153.40      2019.0           0.27760
# 1            NaN     1326.0    74.08      1956.0           0.07864
# 2            NaN     1203.0    94.03      1709.0           0.15990
# 3            NaN      386.1    27.23       567.7           0.28390
# 4            NaN     1297.0    94.44      1575.0           0.13280
# ..           ...        ...      ...         ...               ...
# 564          NaN     1479.0   158.70      2027.0           0.11590
# 565          NaN     1261.0    99.04      1731.0           0.10340
# 566          NaN      858.1    48.55      1124.0           0.10230
# 567          NaN     1265.0    86.22      1821.0           0.27700
# 568          NaN      181.0    19.15       268.6           0.04362
#
#      compactness_se  compactness_worst  concave points_mean  \
# 0           0.04904            0.66560              0.14710
# ...

# %%
data.sort_values(by="area_mean",ascending=True)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 101     862722         B        6.981         13.43           43.79
# 539     921362         B        7.691         25.44           48.34
# 538     921092         B        7.729         25.49           47.98
# 568      92751         B        7.760         24.54           47.92
# 46    85713702         B        8.196         16.84           51.71
# ..         ...       ...          ...           ...             ...
# 82     8611555         M       25.220         24.91          171.50
# 352     899987         M       25.730         17.46          174.20
# 180     873592         M       27.220         21.87          182.10
# 212    8810703         M       28.110         18.47          188.50
# 461  911296202         M       27.420         26.27          186.90
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 101      143.5          0.11700           0.07568         0.00000
# ...

# %%
data[50:70]
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 50    857343         B       11.760         21.60           74.72      427.9
# 51    857373         B       13.640         16.34           87.21      571.8
# 52    857374         B       11.940         18.24           75.71      437.6
# 53    857392         M       18.220         18.70          120.30     1033.0
# 54    857438         M       15.100         22.02           97.26      712.8
# 55  85759902         B       11.520         18.75           73.34      409.0
# 56    857637         M       19.210         18.57          125.50     1152.0
# 57    857793         M       14.710         21.59           95.55      656.9
# 58    857810         B       13.050         19.31           82.61      527.2
# 59    858477         B        8.618         11.79           54.34      224.5
# 60    858970         B       10.170         14.88           64.55      311.9
# ...

# %%
data.loc[:, ["id", "diagnosis"]]
# Out:
#            id diagnosis
# 0      842302         M
# 1      842517         M
# 2    84300903         M
# 3    84348301         M
# 4    84358402         M
# ..        ...       ...
# 564    926424         M
# 565    926682         M
# 566    926954         M
# 567    927241         M
# 568     92751         B
#
# [569 rows x 2 columns]

# %%
a=data.groupby('smoothness_mean')

# %%
dta=data.copy()

# %%
dta
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dta.isna()
# Out:
#         id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    False      False        False         False           False      False
# 1    False      False        False         False           False      False
# 2    False      False        False         False           False      False
# 3    False      False        False         False           False      False
# 4    False      False        False         False           False      False
# ..     ...        ...          ...           ...             ...        ...
# 564  False      False        False         False           False      False
# 565  False      False        False         False           False      False
# 566  False      False        False         False           False      False
# 567  False      False        False         False           False      False
# 568  False      False        False         False           False      False
#
# ...

# %%
dta.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
dta.dropna(how="any")
# Out:
# Empty DataFrame
# Columns: [id, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst, Unnamed: 32]
# Index: []
#
# [0 rows x 33 columns]

# %%
dta.fillna(value=0)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dta=dta.fillna(value=0)

# %%
dta.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
dta=dta.fillna(value=0)

# %%
dta.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
# <ipython-input-60-3d50e71278c5>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill")
#    col
# 0    2
# 1    6
# 2    9
# 3   12
# 4   12
# 5   15
# 6   15
